# %%
import numpy as np
import pandas as pd
import rpy2

# %load_ext rpy2.ipython

ZERO = 1e-5
ONE = 1 - ZERO
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
norming = pd.read_csv("mega-intensionality-norming-v1/mega-intensionality-norming-v1.tsv", sep="\t")

# %%
# Add columns to norming data that appear only in validation data
# cols_not_in_norming = set(validation.columns) - set(norming.columns)
# for c in cols_not_in_norming:
#     norming[c] = None

# Add a column to indicate the task (not technically needed)
norming["task"] = "norming"

# Clip responses for the Beta regression
norming["response"] = norming.response.clip(ZERO, ONE)

norming["scenario"] = norming[["subject", "verb"]].apply(lambda r: "-".join([r[0], r[1]]), axis=1)

# Just verifying that participant numbering starts at 0 for norming data
assert norming.participant.min() == 0

norming.head()
# Out:
#    listid  participant    verb   subject consequent   valence  \
# 0       0           96  notify  mechanic       want  negative
# 1       0           33  notify  mechanic       want  negative
# 2       0            2  notify  mechanic       want  negative
# 3       0           59  notify  mechanic       want  negative
# 4       0           29  notify  mechanic       want  negative
#
#                                             question  response     task  \
# 0  What proportion of mechanics generally want ca...   0.00001  norming
# 1  What proportion of mechanics generally want ca...   0.00001  norming
# 2  What proportion of mechanics generally want ca...   0.17000  norming
# 3  What proportion of mechanics generally want ca...   0.10000  norming
# 4  What proportion of mechanics generally want ca...   0.06000  norming
#
#           scenario
# 0  mechanic-notify
# 1  mechanic-notify
# 2  mechanic-notify
# 3  mechanic-notify
# 4  mechanic-notify

# %%
validation = pd.read_csv("mega-intensionality-validation-v1/mega-intensionality-validation-v1.tsv", sep="\t")
validation.head()
# Out:
#    listid  participant  verb    subject   target consequent  polarity   tense  \
# 0       4          210  know  executive  subject       want  positive  future
# 1       4          319  know  executive  subject       want  positive  future
# 2       4            7  know  executive  subject       want  positive  future
# 3       4          259  know  executive  subject       want  positive  future
# 4       4          308  know  executive  subject       want  positive  future
#
#     valence                                           question  transitivity  \
# 0  positive  The executive knew that his deal would go thro...  intransitive
# 1  positive  The executive knew that his deal would go thro...  intransitive
# 2  positive  The executive knew that his deal would go thro...  intransitive
# 3  positive  The executive knew that his deal would go thro...  intransitive
# 4  positive  The executive knew that his deal would go thro...  intransitive
#
#    response
# 0      0.90
# 1      0.88
# 2      0.97
# 3      0.81
# 4      0.90

# %%
# We need to treat norming and validation participants as distinct;
# Even though this is not strictly true, we have no way of knowing
# based on the data. Norming participant IDs are [0...99] and validation
# participant IDs are [0...419]. To enforce uniqueness across the
# datasets, we just add 1 + max(norming participant ID) to each participant
# ID in the validation data. We could do something similar for the list IDs,
# but we don't use them, and so they can be ignored.
max_norming_participant_id = norming.participant.max()
assert validation.participant.min() == 0
validation["participant"] = validation.participant.apply(lambda x: x + max_norming_participant_id + 1)

# Add "task" column to easily distinguish task (contentful vs. templatic validation)
# (Again, not technically needed)
validation["task"] = np.where(validation["valence"] == "neutral", "templatic", "contentful")

# Column to identify the scenario, same as for norming
# (Does not apply in the templatic case --- hence the None values for these data)
validation["scenario"] = validation[["subject", "verb"]].apply(lambda r: "-".join([r[0], r[1]]), axis=1)
validation.loc[validation.task == "templatic", "scenario"] = None

# Clip responses for the Beta regression
validation["response"] = validation.response.clip(ZERO, ONE)
validation.head()
# Out:
#    listid  participant  verb    subject   target consequent  polarity   tense  \
# 0       4          310  know  executive  subject       want  positive  future
# 1       4          419  know  executive  subject       want  positive  future
# 2       4          107  know  executive  subject       want  positive  future
# 3       4          359  know  executive  subject       want  positive  future
# 4       4          408  know  executive  subject       want  positive  future
#
#     valence                                           question  transitivity  \
# 0  positive  The executive knew that his deal would go thro...  intransitive
# 1  positive  The executive knew that his deal would go thro...  intransitive
# 2  positive  The executive knew that his deal would go thro...  intransitive
# 3  positive  The executive knew that his deal would go thro...  intransitive
# 4  positive  The executive knew that his deal would go thro...  intransitive
#
#    response        task        scenario
# 0      0.90  contentful  executive-know
# 1      0.88  contentful  executive-know
# 2      0.97  contentful  executive-know
# 3      0.81  contentful  executive-know
# 4      0.90  contentful  executive-know

# %%
# Split validation into contentful and templatic dataframes
validation_c = validation[validation.task == "contentful"]
print(len(validation_c))
validation_c.head()
# Out:
# 7680
#    listid  participant  verb    subject   target consequent  polarity   tense  \
# 0       4          310  know  executive  subject       want  positive  future
# 1       4          419  know  executive  subject       want  positive  future
# 2       4          107  know  executive  subject       want  positive  future
# 3       4          359  know  executive  subject       want  positive  future
# 4       4          408  know  executive  subject       want  positive  future
#
#     valence                                           question  transitivity  \
# 0  positive  The executive knew that his deal would go thro...  intransitive
# 1  positive  The executive knew that his deal would go thro...  intransitive
# 2  positive  The executive knew that his deal would go thro...  intransitive
# 3  positive  The executive knew that his deal would go thro...  intransitive
# 4  positive  The executive knew that his deal would go thro...  intransitive
#
#    response        task        scenario
# 0      0.90  contentful  executive-know
# 1      0.88  contentful  executive-know
# 2      0.97  contentful  executive-know
# 3      0.81  contentful  executive-know
# 4      0.90  contentful  executive-know

# %%
validation_t = validation[validation.task == "templatic"]
print(len(validation_t))
validation_t.head()
# Out:
# 7680
#       listid  participant      verb subject  target consequent  polarity  \
# 7680      10          252  persuade       A  object    believe  negative
# 7681      10          252  persuade       A  object       want  positive
# 7682      10          362  persuade       A  object    believe  negative
# 7683      10          362  persuade       A  object       want  positive
# 7684      10          312  persuade       A  object       want  positive
#
#        tense  valence                                           question  \
# 7680  future  neutral  A didn't persuade B that C would happen.How li...
# 7681  future  neutral  A persuaded B that C would happen.How likely i...
# 7682  future  neutral  A didn't persuade B that C would happen.How li...
# 7683  future  neutral  A persuaded B that C would happen.How likely i...
# 7684  future  neutral  A persuaded B that C would happen.How likely i...
#
#      transitivity  response       task scenario
# 7680   transitive      0.19  templatic     None
# 7681   transitive      0.42  templatic     None
# 7682   transitive      0.26  templatic     None
# 7683   transitive      0.34  templatic     None
# 7684   transitive      0.50  templatic     None

# %%
# Split norming, contentful, and validation dataframes based on consequent
w_c = validation_c[validation_c.consequent == "want"]
w_t = validation_t[validation_t.consequent == "want"]
w_n = norming[norming.consequent == "want"]

b_c = validation_c[validation_c.consequent == "believe"]
b_t = validation_t[validation_t.consequent == "believe"]
b_n = norming[norming.consequent == "believe"]

# Verify the number of unique participant IDs
assert w_n.participant.nunique() + w_t.participant.nunique() + w_c.participant.nunique() == 420
assert b_n.participant.nunique() + b_t.participant.nunique() + b_c.participant.nunique() == 420

# Write to output
w_c.to_csv("want_contentful.csv", index=False)
w_t.to_csv("want_templatic.csv", index=False)
w_n.to_csv("want_norming.csv", index=False)

b_c.to_csv("believe_contentful.csv", index=False)
b_t.to_csv("believe_templatic.csv", index=False)
b_n.to_csv("believe_norming.csv", index=False)
